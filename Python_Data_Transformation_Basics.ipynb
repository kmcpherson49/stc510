# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
crime = pd.read_csv('/content/crime_data.csv')
# Out:
# <ipython-input-3-742ac58c5c21>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime = pd.read_csv('/content/crime_data.csv')

# %% [markdown]
# This displays the full dataframe

# %%
crime
# Out:
#            _id       INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 0            1  201600000594484  11/01/2015  00:00                NaN
# 1            2  201500002102327  11/01/2015  00:00  11/01/2015  09:00
# 2            3  201500002168686  11/01/2015  00:00  11/11/2015  09:30
# 3            4  201500002102668  11/01/2015  00:00  11/01/2015  11:50
# 4            5  201600000052855  11/01/2015  00:00  01/09/2016  00:00
# ...        ...              ...                ...                ...
# 219478  219479     201980002225  03/21/2019  22:00                NaN
# 219479  219480     201980002234  03/21/2019  22:00  03/22/2019  08:00
# 219480  219481  201900000481894  03/21/2019  22:00  03/22/2019  08:00
# 219481  219482  201900000479489  03/21/2019  22:00  03/22/2019  00:10
# 219482  219483  201900000479259  03/21/2019  22:20  03/21/2019  22:55
#
#          UCR CRIME CATEGORY            100 BLOCK ADDR      ZIP  \
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219483 entries, 0 to 219482
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   _id                 219483 non-null  int64
#  1   INC NUMBER          219483 non-null  object
#  2   OCCURRED ON         219064 non-null  object
#  3   OCCURRED TO         154625 non-null  object
#  4   UCR CRIME CATEGORY  219483 non-null  object
#  5   100 BLOCK ADDR      219483 non-null  object
#  6   ZIP                 219477 non-null  float64
#  7   PREMISE TYPE        218337 non-null  object
#  8   GRID                218902 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 15.1+ MB

# %% [markdown]
# Grouping of crime by zip code: zip code 85015 had the highest crime rate

# %%
crime.ZIP.value_counts()
# Out:
# 85015.0    11459
# 85008.0    10331
# 85009.0     9554
# 85041.0     9256
# 85051.0     9176
#            ...
# 85337.0        1
# 85381.0        1
# 85266.0        1
# 85203.0        1
# 85335.0        1
# Name: ZIP, Length: 108, dtype: int64

# %% [markdown]
# Grouping of most common crimes: the most common crime committed during this time period was larceny-theft with 27,943 cases.

# %%
crime['UCR CRIME CATEGORY'].value_counts()
# Out:
# LARCENY-THEFT                            111451
# BURGLARY                                  36121
# MOTOR VEHICLE THEFT                       23445
# DRUG OFFENSE                              17467
# AGGRAVATED ASSAULT                        16434
# ROBBERY                                    9423
# RAPE                                       3421
# ARSON                                      1270
# MURDER AND NON-NEGLIGENT MANSLAUGHTER       451
# Name: UCR CRIME CATEGORY, dtype: int64

# %%
crime['UCR CRIME CATEGORY'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Grouping of crime by zip code 2015 vs. 2016

# %%
crime.sort_index()
# Out:
#            _id       INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 0            1  201600000594484  11/01/2015  00:00                NaN
# 1            2  201500002102327  11/01/2015  00:00  11/01/2015  09:00
# 2            3  201500002168686  11/01/2015  00:00  11/11/2015  09:30
# 3            4  201500002102668  11/01/2015  00:00  11/01/2015  11:50
# 4            5  201600000052855  11/01/2015  00:00  01/09/2016  00:00
# ...        ...              ...                ...                ...
# 219478  219479     201980002225  03/21/2019  22:00                NaN
# 219479  219480     201980002234  03/21/2019  22:00  03/22/2019  08:00
# 219480  219481  201900000481894  03/21/2019  22:00  03/22/2019  08:00
# 219481  219482  201900000479489  03/21/2019  22:00  03/22/2019  00:10
# 219482  219483  201900000479259  03/21/2019  22:20  03/21/2019  22:55
#
#          UCR CRIME CATEGORY            100 BLOCK ADDR      ZIP  \
# ...

# %%
crime.sort_values(by=['ZIP', 'OCCURRED ON'])
# Out:
#            _id         INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 10194    10195    202200001168020  01/01/2016  00:00                NaN
# 10199    10200    202200001930670  01/01/2016  00:00                NaN
# 10209    10210    202000001484490  01/01/2016  00:00  12/31/2016  23:00
# 10221    10222    201600000006596  01/01/2016  00:00                NaN
# 10231    10232    201700001689210  01/01/2016  00:00  01/30/2017  00:00
# ...        ...                ...                ...                ...
# 82441    82442  201700000368400.0  02/18/2017  12:00  02/27/2017  15:23
# 219482  219483    201900000479259  03/21/2019  22:20  03/21/2019  22:55
# 174624  174625       201880005657  07/18/2018  03:30  07/18/2018  08:07
# 63137    63138    201700001136425  11/04/2016  00:00  06/25/2017  00:00
# 201278  201279    201800002191378  12/12/2018  13:33                NaN
#
#        UCR CRIME CATEGORY        100 BLOCK ADDR      ZIP  \
# ...

# %%
crime_group = crime.groupby(['ZIP'])

# %%
crime_group.describe()
# Out:
#              _id                                                              \
#            count           mean           std       min        25%       50%
# ZIP
# 85003.0   2671.0  114859.371022  63190.931934      30.0   61298.50  119023.0
# 85004.0   2773.0  110933.972593  63384.193156      69.0   55643.00  107271.0
# 85006.0   4506.0  112034.152463  62993.702138       1.0   59340.75  112596.5
# 85007.0   3512.0  112799.647779  63749.862575      52.0   56630.25  117600.5
# 85008.0  10331.0  108476.538960  61744.767783      16.0   55783.00  108622.0
# ...          ...            ...           ...       ...        ...       ...
# 85383.0      5.0  130667.000000  45021.200434   65098.0  122705.00  136849.0
# 85388.0      2.0  174668.000000  49040.683702  139991.0  157329.50  174668.0
# 85392.0     11.0  100170.818182  58947.163407   23449.0   61477.50   78055.0
# 85395.0      2.0   13315.500000   4297.087909   10277.0   11796.25   13315.5
# ...

# %%
crime_year_one = crime[crime['OCCURRED ON'].str.contains('2015', na=False)]
crime_year_one
# Out:
#          _id       INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 0          1  201600000594484  11/01/2015  00:00                NaN
# 1          2  201500002102327  11/01/2015  00:00  11/01/2015  09:00
# 2          3  201500002168686  11/01/2015  00:00  11/11/2015  09:30
# 3          4  201500002102668  11/01/2015  00:00  11/01/2015  11:50
# 4          5  201600000052855  11/01/2015  00:00  01/09/2016  00:00
# ...      ...              ...                ...                ...
# 10174  10175  201610000020166  12/31/2015  23:32                NaN
# 10175  10176  201600000016798  12/31/2015  23:40  01/03/2016  17:30
# 10176  10177  201500002485103  12/31/2015  23:45                NaN
# 10177  10178  201500002485171  12/31/2015  23:54  12/31/2015  23:54
# 10178  10179  201600000052913  12/31/2015  23:59  01/02/2016  07:00
#
#         UCR CRIME CATEGORY               100 BLOCK ADDR      ZIP  \
# 0                     RAPE            13XX E ALMERIA RD  85006.0
# ...

# %%
crime_year_one_zip = crime_year_one.groupby(['ZIP']).size()
crime_year_one_zip
# Out:
# ZIP
# 85003.0    134
# 85004.0    101
# 85006.0    174
# 85007.0    168
# 85008.0    417
#           ...
# 85310.0     35
# 85331.0     17
# 85339.0    197
# 85353.0    104
# 85363.0      1
# Length: 62, dtype: int64

# %%
crime_year_two = crime[crime['OCCURRED ON'].str.contains('2016', na=False)]
crime_year_two.describe()
# Out:
#                 _id           ZIP
# count  63265.000000  63264.000000
# mean   41902.587908  85044.878920
# std    18310.567954     71.535454
# min    10180.000000  85003.000000
# 25%    26049.000000  85016.000000
# 50%    41908.000000  85027.000000
# 75%    57758.000000  85041.000000
# max    73613.000000  85395.000000

# %%
crime_year_two_zip = crime_year_two.groupby(['ZIP']).size()
crime_year_two_zip
# Out:
# ZIP
# 85003.0     660
# 85004.0     823
# 85006.0    1250
# 85007.0     964
# 85008.0    3032
#            ...
# 85381.0       1
# 85382.0       2
# 85383.0       1
# 85392.0       5
# 85395.0       2
# Length: 88, dtype: int64

# %% [markdown]
# They tracked 26 more zip codes in 2016 than 2015

# %%
crime_type = crime.groupby(['UCR CRIME CATEGORY'])

# %%
crime_type.describe()
# Out:
#                                             _id                               \
#                                           count           mean           std
# UCR CRIME CATEGORY
# AGGRAVATED ASSAULT                      16434.0  115919.117683  61656.224421
# ARSON                                    1270.0  123194.319685  58564.015987
# BURGLARY                                36121.0  102296.471083  62194.219945
# DRUG OFFENSE                            17467.0  116796.404363  64238.956041
# LARCENY-THEFT                          111451.0  110370.145957  63696.052572
# MOTOR VEHICLE THEFT                     23445.0  107292.917040  63362.689825
# MURDER AND NON-NEGLIGENT MANSLAUGHTER     451.0  104534.618625  62258.059015
# RAPE                                     3421.0  110093.249342  63886.867325
# ROBBERY                                  9423.0  111405.974424  62262.476847
#
#                                                                             \
# ...

# %% [markdown]
# This is info on the non-violent crimes

# %%
crime_type.get_group('LARCENY-THEFT')
# Out:
#            _id       INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 1            2  201500002102327  11/01/2015  00:00  11/01/2015  09:00
# 2            3  201500002168686  11/01/2015  00:00  11/11/2015  09:30
# 6            7  201600000527709  11/01/2015  00:00  03/22/2016  00:36
# 8            9  201700001722914  11/01/2015  00:00                NaN
# 10          11  201600000575804  11/01/2015  00:01  03/28/2016  17:20
# ...        ...              ...                ...                ...
# 219475  219476  201900000478780  03/21/2019  21:03  03/21/2019  21:03
# 219478  219479     201980002225  03/21/2019  22:00                NaN
# 219479  219480     201980002234  03/21/2019  22:00  03/22/2019  08:00
# 219480  219481  201900000481894  03/21/2019  22:00  03/22/2019  08:00
# 219482  219483  201900000479259  03/21/2019  22:20  03/21/2019  22:55
#
#        UCR CRIME CATEGORY          100 BLOCK ADDR      ZIP  \
# 1           LARCENY-THEFT          51XX N 15TH ST  85014.0
# ...

# %%
crime_type.get_group('DRUG OFFENSE')
# Out:
#            _id       INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 7            8  201500002103724  11/01/2015  00:00  11/01/2015  15:21
# 59          60  201500002101936  11/01/2015  09:43                NaN
# 60          61  201500002101993  11/01/2015  09:52  11/01/2015  09:52
# 111        112  201500002104200  11/01/2015  15:48                NaN
# 115        116  201500002104138  11/01/2015  16:10  11/01/2015  16:32
# ...        ...              ...                ...                ...
# 219438  219439  201900000478270  03/21/2019  17:50  03/21/2019  18:00
# 219445  219446  201900000477786  03/21/2019  18:06  03/21/2019  18:06
# 219454  219455  201900000478143  03/21/2019  19:03  03/21/2019  19:04
# 219457  219458  201900000478314  03/21/2019  19:32                NaN
# 219468  219469  201900000478684  03/21/2019  20:43                NaN
#
#        UCR CRIME CATEGORY           100 BLOCK ADDR      ZIP  \
# 7            DRUG OFFENSE  54XX W INDIAN SCHOOL RD  85031.0
# ...

# %%
crime_type.get_group('BURGLARY')
# Out:
#            _id       INC NUMBER        OCCURRED ON        OCCURRED TO  \
# 15          16  201600000223791  11/01/2015  00:01  01/30/2016  23:59
# 22          23  201500002102534  11/01/2015  00:01  11/01/2015  03:55
# 23          24  201500002326780  11/01/2015  00:01  12/06/2015  09:45
# 34          35  201500002100875  11/01/2015  02:38  11/01/2015  03:05
# 40          41  201500002101134  11/01/2015  04:25                NaN
# ...        ...              ...                ...                ...
# 219430  219431  201900000481803  03/21/2019  17:00  03/22/2019  11:30
# 219440  219441  201900000497425  03/21/2019  18:00  03/24/2019  22:00
# 219443  219444  201900000478514  03/21/2019  18:00  03/21/2019  19:45
# 219458  219459  201900000478347  03/21/2019  19:38  03/21/2019  19:39
# 219460  219461  201900000478581  03/21/2019  20:00                NaN
#
#        UCR CRIME CATEGORY          100 BLOCK ADDR      ZIP  \
# 15               BURGLARY      40XX E MCDOWELL RD  85008.0
# ...
